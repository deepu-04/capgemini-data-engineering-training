-22', 3), (68, 23, 122, '2024-02-28', 2), (69, 23, 115, '2024-01-02', 3), (70, 59, 119, '2024-02-29', 1), (71, 4, 111, '2024-01-11', 2), (72, 8, 129, '2024-01-09', 3), (73, 5, 105, '2024-01-14', 2), (74, 26, 124, '2024-02-10', 2), (75, 57, 101, '2024-01-09', 3), (76, 43, 109, '2024-02-24', 3), (77, 28, 103, '2024-02-15', 2), (78, 13, 107, '2024-02-06', 2), (79, 32, 107, '2024-01-11', 1), (80, 37, 101, '2024-02-25', 3)], ["sale_id","customer_id","car_id","sale_date","quantity"])
dealers = spark.createDataFrame([(1, 'Dealer1', 'Hyderabad'), (2, 'Dealer2', 'Chennai'), (3, 'Dealer3', 'Mumbai'), (4, 'Dealer4', 'Mumbai'), (5, 'Dealer5', 'Bangalore'), (6, 'Dealer6', 'Bangalore'), (7, 'Dealer7', 'Hyderabad'), (8, 'Dealer8', 'Mumbai'), (9, 'Dealer9', 'Chennai'), (10, 'Dealer10', 'Chennai')], ["dealer_id","name","city"])
sales_dealer = spark.createDataFrame([(1, 8), (2, 7), (3, 10), (4, 8), (5, 4), (6, 9), (7, 4), (8, 5), (9, 1), (10, 9), (11, 2), (12, 3), (13, 1), (14, 10), (15, 8), (16, 4), (17, 1), (18, 6), (19, 3), (20, 9), (21, 9), (22, 2), (23, 4), (24, 10), (25, 3), (26, 5), (27, 9), (28, 3), (29, 4), (30, 10), (31, 4), (32, 5), (33, 7), (34, 3), (35, 5), (36, 4), (37, 1), (38, 2), (39, 1), (40, 1), (41, 5), (42, 1), (43, 7), (44, 5), (45, 1), (46, 2), (47, 5), (48, 8), (49, 1), (50, 5), (51, 10), (52, 9), (53, 10), (54, 2), (55, 2), (56, 1), (57, 3), (58, 8), (59, 6), (60, 4), (61, 2), (62, 7), (63, 8), (64, 4), (65, 1), (66, 6), (67, 6), (68, 7), (69, 9), (70, 6), (71, 7), (72, 5), (73, 6), (74, 8), (75, 3), (76, 4), (77, 3), (78, 10), (79, 5), (80, 2)], ["sale_id","dealer_id"])

sales = sales.withColumn("sale_date", to_date(col("sale_date")))

df = sales.join(customers,"customer_id") \
          .join(cars,"car_id") \
          .join(sales_dealer,"sale_id") \
          .join(dealers,"dealer_id")

# %%
df.groupBy("customer_id").sum("price").show()
# Out:
# +-----------+----------+
# |customer_id|sum(price)|
# +-----------+----------+
# |         17|     86727|
# |         19|     30748|
# |         13|     71084|
# |         50|     55495|
# |          7|     20289|
# |          5|     87212|
# |         49|     76568|
# |          3|     52206|
# |         20|      8760|
# |         48|      8760|
# |         42|     33121|
# |         27|     39765|
# |         34|     84327|
# |         37|     68497|
# |         32|      4531|
# |          6|     47447|
# |         24|     71005|
# |         36|     -1759|
# |         40|     17400|
# |         10|     39733|
# +-----------+----------+
# only showing top 20 rows

# %%
df.printSchema()
sales.printSchema()
cars.printSchema()
customers.printSchema()
dealers.printSchema()
sales_dealer.printSchema()
# Out:
# root
#  |-- dealer_id: long (nullable = true)
#  |-- sale_id: long (nullable = true)
#  |-- car_id: long (nullable = true)
#  |-- customer_id: long (nullable = true)
#  |-- sale_date: date (nullable = true)
#  |-- quantity: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- model: string (nullable = true)
#  |-- price: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#
# root
#  |-- sale_id: long (nullable = true)
#  |-- customer_id: long (nullable = true)
#  |-- car_id: long (nullable = true)
#  |-- sale_date: date (nullable = true)
#  |-- quantity: long (nullable = true)
#
# root
#  |-- car_id: long (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- model: string (nullable = true)
#  |-- price: long (nullable = true)
#
# root
#  |-- customer_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#
# root
#  |-- dealer_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#
# root
#  |-- sale_id: long (nullable = true)
#  |-- dealer_id: long (nullable = true)

# %%
print("customers:", customers.count())
print("cars:", cars.count())
print("sales:", sales.count())
print("dealers:", dealers.count())
print("sales_dealer:", sales_dealer.count())

print("final df:", df.count())
# Out:
# customers: 50
# cars: 30
# sales: 80
# dealers: 10
# sales_dealer: 80
# final df: 63

# %%
df_no_nulls = df.dropna()
df_no_nulls.show()
print("not_nulls", df_no_nulls.count())
# Out:
# +---------+-------+------+-----------+----------+--------+-------+---------+-------+--------+------+--------+---------+
# |dealer_id|sale_id|car_id|customer_id| sale_date|quantity|   name|     city|  brand|   model| price|    name|     city|
# +---------+-------+------+-----------+----------+--------+-------+---------+-------+--------+------+--------+---------+
# |        8|      1|   118|         19|2024-01-29|       2|Cust19 |   Mumbai|  Honda|Model118|  8760| Dealer8|   Mumbai|
# |        7|      2|   104|         13|2024-01-26|       3|Cust13 |  Chennai|  Honda|Model104|-16650| Dealer7|Hyderabad|
# |        8|      4|   103|         17|2024-02-02|       2|Cust17 |  Chennai|  Honda|Model103| 19570| Dealer8|   Mumbai|
# |        9|      6|   101|         50|2024-01-01|       3|Cust50 |Hyderabad| Toyota|Model101| 33507| Dealer9|  Chennai|
# |        4|      7|   122|          7|2024-01-10|       1| Cust7 |Hyderabad|Hyundai|Model122| 20289| Dealer4|   Mumbai|
# |        5|      8|   126|         13|2024-02-29|       2|Cust13 |  Chennai|  Honda|Model126|  8630| Dealer5|Bangalore|
# |        1|      9|   127|          5|2024-02-08|       1| Cust5 |Bangalore|  Honda|Model127| 47447| Dealer1|Hyderabad|
# |        2|     11|   105|         34|2024-01-09|       2|Cust34 |  Chennai|Hyundai|Model105| 39765| Dealer2|  Chennai|
# |        3|     12|   109|         49|2024-01-17|       2|Cust49 |  Chennai|Hyundai|Model109|  -613| Dealer3|   Mumbai|
# |        1|     13|   106|          3|2024-01-31|       1| Cust3 |   Mumbai|  Honda|Model106| 46868| Dealer1|Hyderabad|
# |       10|     14|   118|         20|2024-02-29|       3|Cust20 |Hyderabad|  Honda|Model118|  8760|Dealer10|  Chennai|
# |        8|     15|   104|          3|2024-01-16|       1| Cust3 |   Mumbai|  Honda|Model104|-16650| Dealer8|   Mumbai|
# |        4|     16|   118|         48|2024-01-16|       2|Cust48 |Hyderabad|  Honda|Model118|  8760| Dealer4|   Mumbai|
# |        1|     17|   111|         37|2024-01-05|       1|Cust37 |Bangalore|  Honda|Model111| 34990| Dealer1|Hyderabad|
# |        6|     18|   105|         27|2024-02-05|       3|Cust27 |  Chennai|Hyundai|Model105| 39765| Dealer6|Bangalore|
# |         59|     70|   119|2024-02-29|       1|
# |         57|     75|   101|2024-01-09|       3|
# +-----------+-------+------+----------+--------+

# %%
#Invalid Car Prices
cars.filter(col("price") < 0).show()
# Out:
# +------+-------+--------+------+
# |car_id|  brand|   model| price|
# +------+-------+--------+------+
# |   102|  Honda|Model102| -6970|
# |   104|  Honda|Model104|-16650|
# |   107|Hyundai|Model107| -1271|
# |   108| Toyota|Model108|-18630|
# |   109|Hyundai|Model109|  -613|
# |   116| Toyota|Model116|  -488|
# |   119| Toyota|Model119| -8231|
# +------+-------+--------+------+

# %%
#Invalid Foreign Keys (Car IDs)
sales.join(cars, "car_id", "left_anti").show()
# Out:
# +------+-------+-----------+---------+--------+
# |car_id|sale_id|customer_id|sale_date|quantity|
# +------+-------+-----------+---------+--------+
# +------+-------+-----------+---------+--------+

# %%
#Invalid Dealer Mapping
sales_dealer.join(dealers, "dealer_id", "left_anti").show()
# Out:
# +---------+-------+
# |dealer_id|sale_id|
# +---------+-------+
# +---------+-------+

# %%
s_na=sales.dropna()
print(s_na.count())
c_na=cars.dropna()
print(c_na.count())
d_na=dealers.dropna()
print(d_na.count())
cus_na=customers.dropna()
print(cus_na.count())
sales_de_na=sales_dealer.dropna()
print(sales_de_na.count())
# Out:
# 80
# 30
# 10
# 50
# 80

# %%
customers_clean = customers.fillna({
    "name": "Unknown",
    "city": "Unknown"
})

# %%
cars_clean = cars.fillna({
    "brand": "Unknown",
    "model": "Unknown",
    "price": 0
})

# %%
sales_clean = sales \
    .withColumn("sale_date", col("sale_date").cast("string")) \
    .fillna({
        "sale_date": "Unknown",
        "quantity": 0,
        "customer_id": 0,
        "car_id": 0
    })

# %%
dealers_clean = dealers.fillna({
    "name": "Unknown",
    "city": "Unknown"
})

# %%
sales_dealer_clean = sales_dealer.fillna({
    "sale_id": 0,
    "dealer_id": 0
})

# %%
customers_clean = customers_clean.dropDuplicates(["customer_id"])
cars_clean = cars_clean.dropDuplicates(["car_id"])
sales_clean = sales_clean.dropDuplicates(["sale_id"])
dealers_clean = dealers_clean.dropDuplicates(["dealer_id"])
sales_dealer_clean = sales_dealer_clean.dropDuplicates(["sale_id", "dealer_id"])

# %%
cars_clean = cars_clean.withColumn(
    "price",
    when(col("price") < 0, 0).otherwise(col("price"))
)

# %%
from pyspark.sql.functions import *

customers_clean = customers_clean \
    .withColumn("name", trim(col("name"))) \
    .withColumn("city", trim(col("city")))

cars_clean = cars_clean \
    .withColumn("brand", trim(col("brand"))) \
    .withColumn("model", trim(col("model")))

sales_clean = sales_clean \
    .withColumn("sale_date", to_date(trim(col("sale_date")), "yyyy-MM-dd"))

dealers_clean = dealers_clean \
    .withColumn("name", trim(col("name"))) \
    .withColumn("city", trim(col("city")))

# %%
sales_clean = sales_clean.join(
    customers_clean, "customer_id", "inner"
)
sales_clean = sales_clean.join(
    cars_clean, "car_id", "inner"
)
sales_dealer_clean = sales_dealer_clean.join(
    sales_clean, "sale_id", "inner"
)
sales_dealer_clean = sales_dealer_clean.join(
    dealers_clean, "dealer_id", "inner"
)

# %%
invalid_customers = sales.join(
    customers, "customer_id", "left_anti"
)

invalid_customers.show()
# Out:
# +-----------+-------+------+----------+--------+
# |customer_id|sale_id|car_id| sale_date|quantity|
# +-----------+-------+------+----------+--------+
# |         55|      3|   123|2024-01-14|       1|
# |         52|      5|   116|2024-02-25|       1|
# |         54|     10|   128|2024-01-21|       3|
# |         52|     19|   110|2024-01-04|       2|
# |         60|     34|   121|2024-03-01|       2|
# |         53|     35|   128|2024-01-08|       2|
# |         51|     40|   118|2024-01-26|       2|
# |         59|     41|   116|2024-02-12|       1|
# |         57|     47|   126|2024-02-08|       1|
# |         58|     48|   103|2024-02-19|       1|
# |         54|     49|   126|2024-01-21|       2|
# |         56|     56|   120|2024-02-29|       1|
# |         57|     58|   105|2024-01-18|       2|
# |         51|     59|   103|2024-01-26|       3|
# |         54|     60|   114|2024-02-04|       1|
# |         59|     70|   119|2024-02-29|       1|
# |         57|     75|   101|2024-01-09|       3|
# +-----------+-------+------+----------+--------+

# %%
invalid_cars = sales.join(
    cars, "car_id", "left_anti"
)

invalid_cars.show()
# Out:
# +------+-------+-----------+---------+--------+
# |car_id|sale_id|customer_id|sale_date|quantity|
# +------+-------+-----------+---------+--------+
# +------+-------+-----------+---------+--------+

# %%
invalid_sales = sales_dealer.join(
    sales, "sale_id", "left_anti"
)

invalid_sales.show()
# Out:
# +-------+---------+
# |sale_id|dealer_id|
# +-------+---------+
# +-------+---------+

# %%
invalid_dealers = sales_dealer.join(
    dealers, "dealer_id", "left_anti"
)

invalid_dealers.show()
# Out:
# +---------+-------+
# |dealer_id|sale_id|
# +---------+-------+
# +---------+-------+

# %%
final_df = sales_clean.join(customers_clean,"customer_id") \
          .join(cars_clean ,"car_id") \
          .join(sales_dealer_clean,"sale_id") \
          .join(dealers_clean,"dealer_id")

# %%
display(final_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dealer_id</th><th>sale_id</th><th>car_id</th><th>customer_id</th><th>sale_date</th><th>quantity</th><th>name</th><th>city</th><th>brand</th><th>model</th><th>price</th><th>name</th><th>city</th><th>brand</th><th>model</th><th>price</th><th>car_id</th><th>customer_id</th><th>sale_date</th><th>quantity</th><th>name</th><th>city</th><th>brand</th><th>model</th><th>price</th><th>name</th><th>city</th><th>name</th><th>city</th></tr></thead><tbody><tr><td>1</td><td>9</td><td>127</td><td>5</td><td>2024-02-08</td><td>1</td><td>Cust5</td><td>Bangalore</td><td>Honda</td><td>Model127</td><td>47447</td><td>Cust5</td><td>Bangalore</td><td>Honda</td><td>Model127</td><td>47447</td><td>127</td><td>5</td><td>2024-02-08</td><td>1</td><td>Cust5</td><td>Bangalore</td><td>Honda</td><td>Model127</td><td>47447</td><td>Dealer1</td><td>Hyderabad</td><td>Dealer1</td><td>Hyderabad</td></tr><tr><td>8</td><td>4</td><td>103</td><td>17</td><td>2024-02-02</td><td>2</td><td>Cust17</td><td>Chennai</td><td>Honda</td><td>Model103</td><td>19570</td><td>Cust17</td><td>Chennai</td><td>Honda</td><td>Model103</td
    .join(cars_clean.alias("car"), "car_id") \
    .join(sales_dealer_clean.alias("sd"), "sale_id") \
    .join(dealers_clean.alias("d"), "dealer_id") \
    .select(
        col("s.sale_id"),
        col("s.customer_id"),   
        col("c.name").alias("name"),
        col("c.city").alias("city"),
        col("s.car_id"),
        col("car.brand"),
        col("car.model"),
        col("car.price"),
        col("s.sale_date"),
        col("s.quantity"),
        col("d.dealer_id"),
        col("d.name").alias("dealer_name"),
        col("d.city").alias("dealer_city")
    )

# %%
from pyspark.sql.functions import sum

df = df.withColumn("revenue", col("price") * col("quantity"))

# %%
df.groupBy("customer_id", "name") \
  .agg(sum("revenue").alias("total_revenue")) \
  .show()
# Out:
# +-----------+------+-------------+
# |customer_id|  name|total_revenue|
# +-----------+------+-------------+
# |          5| Cust5|       126977|
# |         17|Cust17|       220322|
# |         50|Cust50|       144497|
# |         13|Cust13|       178010|
# |          7| Cust7|        20289|
# |         19|Cust19|        83484|
# |         34|Cust34|       213216|
# |         20|Cust20|        26280|
# |         37|Cust37|       135511|
# |          3| Cust3|        68856|
# |         42|Cust42|        99363|
# |         49|Cust49|       109800|
# |         48|Cust48|        17520|
# |         27|Cust27|       119295|
# |         10|Cust10|        39733|
# |          6| Cust6|        94894|
# |         40|Cust40|        34800|
# |         32|Cust32|        39852|
# |         41|Cust41|       154246|
# |         24|Cust24|       183499|
# +-----------+------+-------------+
# only showing top 20 rows

# %%
df.groupBy("brand") \
  .agg(sum("revenue").alias("total_sales")) \
  .show()
# Out:
# +-------+-----------+
# |  brand|total_sales|
# +-------+-----------+
# |  Honda|    1173453|
# | Toyota|     707803|
# |Hyundai|     881130|
# +-------+-----------+

# %%
df.groupBy("city") \
  .agg(sum("revenue").alias("total_revenue")) \
  .show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|       359958|
# |  Chennai|       999946|
# |Hyderabad|       670516|
# |   Mumbai|       731966|
# +---------+-------------+

# %%
dealer_revenue = df.groupBy("dealer_id", "dealer_name") \
    .agg(sum("revenue").alias("total_revenue"))

dealer_revenue.show()
# Out:
# +---------+-----------+-------------+
# |dealer_id|dealer_name|total_revenue|
# +---------+-----------+-------------+
# |        1|    Dealer1|       320321|
# |        8|    Dealer8|        70768|
# |        9|    Dealer9|       374625|
# |        7|    Dealer7|       198510|
# |        4|    Dealer4|       217117|
# |        5|    Dealer5|       289368|
# |        2|    Dealer2|       671492|
# |       10|   Dealer10|       198991|
# |        3|    Dealer3|        78873|
# |        6|    Dealer6|       342321|
# +---------+-----------+-------------+

# %%
top_dealers = dealer_revenue.orderBy(desc("total_revenue"))

top_dealers.show()
# Out:
# +---------+-----------+-------------+
# |dealer_id|dealer_name|total_revenue|
# +---------+-----------+-------------+
# |        2|    Dealer2|       671492|
# |        9|    Dealer9|       374625|
# |        6|    Dealer6|       342321|
# |        1|    Dealer1|       320321|
# |        5|    Dealer5|       289368|
# |        4|    Dealer4|       217117|
# |       10|   Dealer10|       198991|
# |        7|    Dealer7|       198510|
# |        3|    Dealer3|        78873|
# |        8|    Dealer8|        70768|
# +---------+-----------+-------------+

# %%
dealer_city = df.groupBy("dealer_city", "dealer_id", "dealer_name") \
    .agg(sum("revenue").alias("total_revenue"))

dealer_city.show()
# Out:
# +-----------+---------+-----------+-------------+
# |dealer_city|dealer_id|dealer_name|total_revenue|
# +-----------+---------+-----------+-------------+
# |  Hyderabad|        1|    Dealer1|       320321|
# |     Mumbai|        8|    Dealer8|        70768|
# |    Chennai|        9|    Dealer9|       374625|
# |  Hyderabad|        7|    Dealer7|       198510|
# |     Mumbai|        4|    Dealer4|       217117|
# |  Bangalore|        5|    Dealer5|       289368|
# |    Chennai|        2|    Dealer2|       671492|
# |    Chennai|       10|   Dealer10|       198991|
# |     Mumbai|        3|    Dealer3|        78873|
# |  Bangalore|        6|    Dealer6|       342321|
# +-----------+---------+-----------+-------------+

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import sum, dense_rank

# total revenue per customer per city
cust_city = df.groupBy("city", "customer_id", "name") \
    .agg(sum("revenue").alias("total_revenue"))

# ranking
window = Window.partitionBy("city").orderBy(col("total_revenue").desc())

top3_customers = cust_city \
    .withColumn("rank", dense_rank().over(window)) \
    .filter(col("rank") <= 3)

top3_customers.show()
# Out:
# +---------+-----------+------+-------------+----+
# |     city|customer_id|  name|total_revenue|rank|
# +---------+-----------+------+-------------+----+
# |Bangalore|         37|Cust37|       135511|   1|
# |Bangalore|          5| Cust5|       126977|   2|
# |Bangalore|         12|Cust12|        65964|   3|
# |  Chennai|         17|Cust17|       220322|   1|
# |  Chennai|         34|Cust34|       213216|   2|
# |  Chennai|         13|Cust13|       178010|   3|
# |Hyderabad|         24|Cust24|       183499|   1|
# |Hyderabad|         23|Cust23|       147509|   2|
# |Hyderabad|         50|Cust50|       144497|   3|
# |   Mumbai|         41|Cust41|       154246|   1|
# |   Mumbai|          4| Cust4|       133266|   2|
# |   Mumbai|         42|Cust42|        99363|   3|
# +---------+-----------+------+-------------+----+

# %%
from pyspark.sql.functions import month

monthly_trend = df.groupBy(month("sale_date").alias("month")) \
    .agg(sum("revenue").alias("total_revenue")) \
    .orderBy("month")

monthly_trend.show()
# Out:
# +-----+-------------+
# |month|total_revenue|
# +-----+-------------+
# |    1|      1105497|
# |    2|      1617156|
# |    3|        39733|
# +-----+-------------+

# %%
repeat_customers = df.groupBy("customer_id", "name") \
    .count() \
    .filter(col("count") > 1)

repeat_customers.show()
# Out:
# +-----------+------+-----+
# |customer_id|  name|count|
# +-----------+------+-----+
# |         13|Cust13|    5|
# |         50|Cust50|    2|
# |         19|Cust19|    2|
# |          5| Cust5|    2|
# |         29|Cust29|    2|
# |         34|Cust34|    2|
# |          3| Cust3|    3|
# |         49|Cust49|    3|
# |         37|Cust37|    2|
# |         28|Cust28|    2|
# |          4| Cust4|    2|
# |         41|Cust41|    2|
# |         24|Cust24|    3|
# |         17|Cust17|    3|
# |         32|Cust32|    4|
# |         23|Cust23|    3|
# |         36|Cust36|    2|
# +-----------+------+-----+

# %%
df.write \
  .mode("overwrite") \
  .option("header", True) \
  .csv("/Volumes/workspace/default/samples_vol/day6_final_dataset_output")
