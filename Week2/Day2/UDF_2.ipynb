# %% [markdown]
# ### WHY DO WE NEED UDF?

# %% [markdown]
# ### Can we write every logic using built-in functions?

# %% [markdown]
# ### Example Problem

# %%
If salary is NULL → "Unknown"
If salary > 6000 → "A"
Else → "B"
Too complex
Not directly available in PySpark functions

# %% [markdown]
# ### WHAT IS UDF?
# ### UDF = User Defined Function
# ### It means:
# ### “You write your own Python function and apply it on DataFrame columns”

# %% [markdown]
# ### Create normal Python function

# %%
def grade(salary):
    if salary is None:
        return "Unknown"
    elif salary > 6000:
        return "A"
    else:
        return "B"

# %% [markdown]
# ### Convert to UDF

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import StringType

grade_udf = udf(grade, StringType())

# %% [markdown]
# ### Spark doesn’t understand Python directly
# ### So we “wrap” function into UDF
# ### Must specify return type

# %% [markdown]
# ### Apply on DataFrame

# %%
data = [
    (1, "A", None),
    (2, "B", 5000),
    (3, None, 7000),
    (4, "D", None)
]
df = spark.createDataFrame(data, ["id", "name", "salary"])

# %%
df = df.withColumn("grade", grade_udf(df.salary))
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>salary</th><th>grade</th></tr></thead><tbody><tr><td>1</td><td>A</td><td>null</td><td>Unknown</td></tr><tr><td>2</td><td>B</td><td>5000</td><td>B</td></tr><tr><td>3</td><td>null</td><td>7000</td><td>A</td></tr><tr><td>4</td><td>D</td><td>null</td><td>Unknown</td></tr></tbody></table></div>
